# %% [markdown]
# <a href="https://colab.research.google.com/github/YousefBarty/AI-Projects/blob/main/Auto_Correct.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install autocorrect
# Out:
# Collecting autocorrect
#   Downloading autocorrect-2.6.1.tar.gz (622 kB)
#      |████████████████████████████████| 622 kB 25.0 MB/s
# Building wheels for collected packages: autocorrect
#   Building wheel for autocorrect (setup.py) ... done
#   Created wheel for autocorrect: filename=autocorrect-2.6.1-py3-none-any.whl size=622382 sha256=6eb3f4a1833c1e445bfd1c2ef85e4c7bd39afb5129bedd0521424e2b9889ed3b
#   Stored in directory: /root/.cache/pip/wheels/54/d4/37/8244101ad50b0f7d9bffd93ce58ed7991ee1753b290923934b
# Successfully built autocorrect
# Installing collected packages: autocorrect
# Successfully installed autocorrect-2.6.1

# %%
pip install pyspellchecker
# Out:
# Collecting pyspellchecker
#   Downloading pyspellchecker-0.6.3-py3-none-any.whl (2.7 MB)
#      |████████████████████████████████| 2.7 MB 13.8 MB/s
# Installing collected packages: pyspellchecker
# Successfully installed pyspellchecker-0.6.3

# %%
pip install textblob
# Out:
# Requirement already satisfied: textblob in /usr/local/lib/python3.7/dist-packages (0.15.3)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.7/dist-packages (from textblob) (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk>=3.1->textblob) (1.15.0)

# %%
from autocorrect import Speller
spell = Speller(lang='en')
spell("I'm not sleapy and tehre is no place I'm giong to.")
# Out:
# "I'm not sleepy and there is no place I'm going to."

# %%
spell("hello my friend i want to see you omorrow")
# Out:
# 'hello my friend i want to see you tomorrow'

# %%
spell("tehre")
# Out:
# 'there'

# %%
spell("does this sentece have misspelled wordz?")
# Out:
# 'does this sentence have misspelled word?'

# %%
from spellchecker import SpellChecker
 
spell = SpellChecker()

# %%
spell.correction("addresz")
# Out:
# 'address'

# %%
spell.correction("besause")
# Out:
# 'because'

# %%
spell.correction("sleapy") , spell.correction("tehre") , spell.correction("giong")
# Out:
# ('sleepy', 'there', 'going')

# %%
words = spell.split_words("this sentnce has mizspelled werds")
[spell.correction(word) for word in words]
# Out:
# ['this', 'sentence', 'has', 'misspelled', 'words']

# %%
spell.candidates("conceed")
# Out:
# {'concede', 'conceded', 'concemed'}

# %%
spell.candidates("meaj")
# Out:
# {'maj', 'mea', 'mead', 'meal', 'meam', 'mean', 'mear', 'meas', 'meat', 'mesaj'}

# %%
from textblob import Word
 
word = Word('percieve')
 
word.spellcheck()
# Out:
# [('perceive', 1.0)]

# %%
word = Word('personell')
word.spellcheck()
# Out:
# [('personal', 0.65),
#  ('personally', 0.2642857142857143),
#  ('peroneal', 0.06428571428571428),
#  ('personnel', 0.014285714285714285),
#  ('personen', 0.007142857142857143)]

# %%
word = Word('meaj')
word.spellcheck()
# Out:
# [('mean', 0.7538461538461538),
#  ('meat', 0.11538461538461539),
#  ('meal', 0.11538461538461539),
#  ('mead', 0.015384615384615385)]
